# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import cluster
import numpy as np

# %%
data = gpd.read_parquet("dat_f_m.parquet")

# %%
# prg = data[data["naz_kraj"]=="Hlavní město Praha"]

# %%
data = data.drop(
    columns=["Obyvatelstvo celkem", "Hospodařící domácnosti v bytech celkem"]
)

# %%
fa = data.columns[13:]

# %%
fa = [
    "Obyvatelstvo - věk: 0 - 14  - ženy",
    "Obyvatelstvo - věk: 15 - 39  - ženy",
    "Obyvatelstvo - věk: 40 - 64  - ženy",
    "Obyvatelstvo - věk: 65 a více - ženy",
    "Obyvatelstvo - věk: 0 - 14  - muži",
    "Obyvatelstvo - věk: 15 - 39  - muži",
    "Obyvatelstvo - věk: 40 - 64  - muži",
    "Obyvatelstvo - věk: 65 a více - muži",
    "Počet osob v bytech celkem  s právním důvodem užívání: ve vlastním domě",
    "Počet osob v bytech celkem  s právním důvodem užívání: v osobním vlastnictví",
    "Počet obyvatel na byt",
    "Počet osob v bytech celkem  - se 3 obytnými místnostmi",
    "Obyvatelstvo - státní občanství: Česká republika - muži",
    "Obyvatelstvo - státní občanství: Slovenská republika - muži",
    "Obyvatelstvo - státní občanství: Slovenská  republika - ženy",
    "Obyvatelstvo - státní občanství: země EU mimo ČR - muži",
    "Obyvatelstvo - státní občanství: nezjištěno - muži",
    "Obyvatelstvo - státní občanství: nezjištěno - ženy",
    "Obyvatelstvo - ekon. aktivita: zaměstnaní - ženy",
    "Obyvatelstvo - mimo pracovní sílu - muži",
    "Obyvatelstvo - mimo pracovní sílu - ženy",
    "Obyvatelstvo - ekon. aktivita: osoby v domácnosti, děti předškolního věku, ostatní závislé osoby - muži",
    "Obyvatelstvo - ekon. aktivita: osoby v domácnosti, děti předškolního věku, ostatní závislé osoby - ženy",
    "Obyvatelstvo - ekon. aktivita: žáci, studenti - muži",
    "Obyvatelstvo - ekon. aktivita: žáci, studenti - ženy",
    "Obyvatelstvo - ekon. aktivita: nezjištěno - muži",
    "Obyvatelstvo - věk: 15 a více - nejvyšší dosažené vzdělání: - střední s maturitou vč. nástavbového a pomaturitního - ženy",
    "Obyvatelstvo - věk: 15 a více - nejvyšší dosažené vzdělání:  vysokoškolské - muži",
    "Obyvatelstvo - věk: 15 a více - nejvyšší dosažené vzdělání:  vysokoškolské- ženy",
    "Obyvatelstvo - věk: 15 a více - nejvyšší dosažené vzdělání: nezjištěno - muži",
    "Zaměstnaní - Specialisté - muži",
    "Zaměstnaní - Řemeslníci a opraváři - muži",
    "Zaměstnaní - Specialisté - ženy",
    "Zaměstnaní - Pracovníci ve službách a prodeji - ženy",
    "Zaměstnaní - nezjištěno - ženy",
    "Obyvatelstvo - zaměstnaní - postavení v zaměstnání: zaměstnanci - celkem",
    "Obyvatelstvo - zaměstnaní - odvětví ekon.čin.: zemědělství, lesnictví ,rybářství - celkem",
    "Obyvatelstvo - zaměstnaní - odvětví ekon.čin.: průmysl - celkem",
    "Obyvatelstvo - zaměstnaní - odvětví ekon.čin.: doprava a skladování - celkem",
    "Obyvatelstvo - zaměstnaní - odvětví ekon.čin.: informační a komunikační činnosti - celkem",
    "Hospodařící domácnosti v bytech - typ HD: domácnosti jednotlivců",
    "Obyvatelstvo - rodinný stav: svobodní  - muži",
    "Obyvatelstvo - rodinný stav: svobodní  - ženy",
    "Obyvatelstvo - rodinný stav: ženatí, vdané - muži",
    "Obyvatelstvo - rodinný stav: nezjištěno - ženy",
    "Obyvatelstvo - náboženská víra: věřící - nehlásící se k církvi, náboženské společnosti nebo směru - ženy",
    "Obyvatelstvo - náboženská víra: věřící - hlásící se k církvi, náboženské společnosti nebo směru - muži",
    "Obyvatelstvo - náboženská víra: bez náboženské víry - muži",
    "Obyvatelstvo - náboženská víra: bez náboženské víry - ženy",
    "Obyvatelstvo - náboženská víra: neuvedeno - muži",
    "Obyvatelstvo - náboženská víra: neuvedeno - ženy",
    "Obyvatelstvo - s trvalým pobytem - ženy",
    "Obyvatelstvo - s dlouhodobým pobytem - muži",
    "Obyvatelstvo - bydliště po narození v obci obvyklého bydliště - muži",
    "Obyvatelstvo - bydliště po narození v obci obvyklého bydliště - ženy",
    "Obyvatelstvo - bydlící před rokem ve stejné obci - muži",
    "Obyvatelstvo - bydlící v bytech - muži",
    "Obyvatelstvo - bydlící v bytech - ženy",
    "Obyvatelstvo - bydlící v zařízeních - muži",
    "Obyvatelstvo - bydlící v zařízeních - ženy",
    "Obyvatelstvo - bydlící mimo byty a zařízení - muži",
    "kmeans_fa",
]

# %%
inertias = {}

for k in range(2, 50):
    kmeans = cluster.KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data[fa])
    inertias[k] = kmeans.inertia_

# %%
# Assuming 'inertias' is a dictionary or list where keys/index are your N values
inertia_series = pd.Series(inertias)

plt.figure(figsize=(20, 10))
ax = inertia_series.plot(marker="o", linestyle="-", color="b")

# This is the "all the ticks" magic:
# We tell the axis to use every single value in the index
plt.xticks(inertia_series.index)

plt.title("Inertia (WCSS) across PC Iterations", fontsize=16)
plt.xlabel("Number of PCs (N)", fontsize=12)
plt.ylabel("Inertia", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.7)

plt.show()

# %%
from clustergram import Clustergram

cgram = Clustergram(range(1, 30))
cgram.fit(data[fa])

# %%
cgram

# %%
# 1. Create the plot
ax = cgram.plot(figsize=(20, 30))
ax.set_xticks(np.arange(1, 31))
ax.grid(True, which="both", color="black", linestyle="-", linewidth=0.5)

# %%
kmeans5 = cluster.KMeans(n_clusters=3, random_state=42)

# %%
kmeans5.fit(data[fa])

# %%
k = 3
labels = kmeans5.labels_

# Sort cluster centers by the first feature
sorted_centers_indices = np.argsort(kmeans5.cluster_centers_[:, 0])

# Reassign labels: the cluster with the smallest center gets label 0, etc.
new_labels = np.zeros_like(labels)
for i, cluster_idx in enumerate(sorted_centers_indices):
    new_labels[labels == cluster_idx] = i

data["kmeans_fa"] = new_labels

# %%
data[["kmeans_fa", "geometry"]].plot(
    "kmeans_fa",
    categorical=True,
)

# %%
k5_means = data.groupby("kmeans_fa")[fa].mean()
k5_means.T.style.background_gradient(cmap="coolwarm", vmin=-5, vmax=5, axis=1)

# %%
df = data[fa]

# %%
import numpy as np
import matplotlib.pyplot as plt

cluster_col = "kmeans_fa"
var_cols = [c for c in fa if c != cluster_col]

short_names = [
    "Age 0–14 (F)",
    "Age 15–39 (F)",
    "Age 40–64 (F)",
    "Age 65+ (F)",
    "Age 0–14 (M)",
    "Age 15–39 (M)",
    "Age 40–64 (M)",
    "Age 65+ (M)",
    "Owner-occupied (house)",
    "Owner-occupied (flat)",
    "Persons per dwelling",
    "3-room dwellings",
    "Czech citizen (M)",
    "Slovak citizen (M)",
    "Slovak citizen (F)",
    "EU citizen (M)",
    "Unknown citizenship (M)",
    "Unknown citizenship (F)",
    "Employed (F)",
    "Outside labour force (M)",
    "Outside labour force (F)",
    "Homemakers & dependants (M)",
    "Homemakers & dependants (F)",
    "Students (M)",
    "Students (F)",
    "Economic activity unknown (M)",
    "Secondary w/ matura (F)",
    "University degree (M)",
    "University degree (F)",
    "Education unknown (M)",
    "Specialists (M)",
    "Craft & repair (M)",
    "Specialists (F)",
    "Service & sales (F)",
    "Occupation unknown (F)",
    "Employees (total)",
    "Agriculture sector",
    "Industry sector",
    "Transport & storage",
    "ICT sector",
    "Single-person households",
    "Single/never married (M)",
    "Single/never married (F)",
    "Married (M)",
    "Marital status unknown (F)",
    "Religious non-affiliated (F)",
    "Religious affiliated (M)",
    "No religion (M)",
    "No religion (F)",
    "Religion not stated (M)",
    "Religion not stated (F)",
    "Permanent residents (F)",
    "Long-term residents (M)",
    "Born in municipality (M)",
    "Born in municipality (F)",
    "Same municipality 1yr ago (M)",
    "Living in dwellings (M)",
    "Living in dwellings (F)",
    "Living in institutions (M)",
    "Living in institutions (F)",
    "Living outside dwellings (M)",
]

cluster_means = df.groupby(cluster_col)[var_cols].mean()

N = len(var_cols)
angles = np.linspace(0, 2 * np.pi, N, endpoint=False).tolist()
angles += angles[:1]

colors = plt.cm.tab10.colors

fig, ax = plt.subplots(figsize=(13, 13), subplot_kw=dict(polar=True))

for i, (cluster_id, row) in enumerate(cluster_means.iterrows()):
    vals = row.tolist() + row.tolist()[:1]
    color = colors[i % len(colors)]
    ax.plot(angles, vals, linewidth=2, label=f"Cluster {cluster_id}", color=color)
    ax.fill(angles, vals, alpha=0.07, color=color)

ax.set_xticks(angles[:-1])
ax.set_xticklabels(short_names, fontsize=7)
ax.set_title("Geodemographic Cluster Profiles (z-scores)", fontsize=14, pad=25)
ax.set_rlabel_position(0)
ax.yaxis.set_tick_params(labelsize=8)
ax.legend(loc="upper right", bbox_to_anchor=(1.45, 1.15), fontsize=10)

# Rotate labels to follow the chart angle
for label, angle in zip(ax.get_xticklabels(), angles[:-1]):
    angle_deg = np.degrees(angle)
    if 90 < angle_deg < 270:
        label.set_rotation(angle_deg + 180)
    else:
        label.set_rotation(angle_deg)
    label.set_horizontalalignment("center")

plt.tight_layout()
plt.savefig("spider_chart.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# # PCA

# %%
# prg = data[data["naz_kraj"]=="Hlavní město Praha"]

# %%
pca = data.columns[13:]

# %%
pca = [
    "Obyvatelstvo - věk: 0 - 14  - ženy",
    "Obyvatelstvo - věk: 15 - 39  - ženy",
    "Obyvatelstvo - věk: 40 - 64  - ženy",
    "Obyvatelstvo - věk: 65 a více - ženy",
    "Obyvatelstvo - věk: 0 - 14  - muži",
    "Obyvatelstvo - věk: 15 - 39  - muži",
    "Obyvatelstvo - věk: 40 - 64  - muži",
    "Obyvatelstvo - věk: 65 a více - muži",
    "Počet osob v bytech celkem  s právním důvodem užívání: ve vlastním domě",
    "Počet osob v bytech celkem  s právním důvodem užívání: v osobním vlastnictví",
    "Počet obyvatel na byt",
    "Obyvatelstvo - státní občanství: Česká republika - muži",
    "Obyvatelstvo - státní občanství: Slovenská  republika - ženy",
    "Obyvatelstvo - státní občanství: země EU mimo ČR - muži",
    "Obyvatelstvo - státní občanství: nezjištěno - muži",
    "Obyvatelstvo - státní občanství: nezjištěno - ženy",
    "Obyvatelstvo - ekon. aktivita: zaměstnaní - muži",
    "Obyvatelstvo - ekon. aktivita: zaměstnaní - ženy",
    "Obyvatelstvo - ekon. aktivita: osoby na mateřské dovolené - muži",
    "Obyvatelstvo - mimo pracovní sílu - muži",
    "Obyvatelstvo - mimo pracovní sílu - ženy",
    "Obyvatelstvo - ekon. aktivita: osoby v domácnosti, děti předškolního věku, ostatní závislé osoby - muži",
    "Obyvatelstvo - ekon. aktivita: žáci, studenti - muži",
    "Obyvatelstvo - ekon. aktivita: žáci, studenti - ženy",
    "Obyvatelstvo - věk: 15 a více - nejvyšší dosažené vzdělání: - střední vč. vyučení bez maturity - muži",
    "Obyvatelstvo - věk: 15 a více - nejvyšší dosažené vzdělání:  vysokoškolské - muži",
    "Obyvatelstvo - věk: 15 a více - nejvyšší dosažené vzdělání:  vysokoškolské- ženy",
    "Obyvatelstvo - věk: 15 a více - nejvyšší dosažené vzdělání: nezjištěno - muži",
    "Zaměstnaní - Specialisté - muži",
    "Zaměstnaní - Řemeslníci a opraváři - muži",
    "Zaměstnaní - Specialisté - ženy",
    "Obyvatelstvo - zaměstnaní - postavení v zaměstnání: zaměstnanci - celkem",
    "Obyvatelstvo - zaměstnaní - odvětví ekon.čin.: zemědělství, lesnictví ,rybářství - celkem",
    "Obyvatelstvo - zaměstnaní - odvětví ekon.čin.: průmysl - celkem",
    "Obyvatelstvo - zaměstnaní - odvětví ekon.čin.: stavebnictví - celkem",
    "Hospodařící domácnosti v bytech - typ HD: domácnosti jednotlivců",
    "Hospodařící domácnosti v bytech - typ HD: rodinné domácnosti tvořené 1 rodinou - úplná rodina bez závislých dětí",
    "Hospodařící domácnosti v bytech - typ HD: rodinné domácnosti tvořené 1 rodinou - úplná rodina se závislými dětmi",
    "Obyvatelstvo - rodinný stav: svobodní  - muži",
    "Obyvatelstvo - rodinný stav: svobodní  - ženy",
    "Obyvatelstvo - rodinný stav: ženatí, vdané - muži",
    "Obyvatelstvo - rodinný stav: nezjištěno - ženy",
    "Obyvatelstvo - náboženská víra: věřící - nehlásící se k církvi, náboženské společnosti nebo směru - muži",
    "Obyvatelstvo - náboženská víra: věřící - nehlásící se k církvi, náboženské společnosti nebo směru - ženy",
    "Obyvatelstvo - náboženská víra: věřící - hlásící se k církvi, náboženské společnosti nebo směru - muži",
    "Obyvatelstvo - náboženská víra: bez náboženské víry - muži",
    "Obyvatelstvo - náboženská víra: bez náboženské víry - ženy",
    "Obyvatelstvo - náboženská víra: neuvedeno - muži",
    "Obyvatelstvo - náboženská víra: neuvedeno - ženy",
    "Obyvatelstvo - s trvalým pobytem - ženy",
    "Obyvatelstvo - s dlouhodobým pobytem - muži",
    "Obyvatelstvo - s dlouhodobým pobytem - ženy",
    "Obyvatelstvo - bydliště po narození v obci obvyklého bydliště - muži",
    "Obyvatelstvo - bydliště po narození v obci obvyklého bydliště - ženy",
    "Obyvatelstvo - bydlící před rokem ve stejné obci - muži",
    "Obyvatelstvo - bydlící v bytech - muži",
    "Obyvatelstvo - bydlící v bytech - ženy",
    "Obyvatelstvo - bydlící v zařízeních - muži",
    "Obyvatelstvo - bydlící v zařízeních - ženy",
    "Obyvatelstvo - bydlící mimo byty a zařízení - muži",
]

# %%
inertias = {}

for k in range(2, 50):
    kmeans = cluster.KMeans(n_clusters=k, random_state=42)
    kmeans.fit(data[pca])
    inertias[k] = kmeans.inertia_

# %%
import matplotlib.pyplot as plt

# Assuming 'inertias' is a dictionary or list where keys/index are your N values
inertia_series = pd.Series(inertias)

plt.figure(figsize=(20, 10))
ax = inertia_series.plot(marker="o", linestyle="-", color="b")

# This is the "all the ticks" magic:
# We tell the axis to use every single value in the index
plt.xticks(inertia_series.index)

plt.title("Inertia (WCSS) across PC Iterations", fontsize=16)
plt.xlabel("Number of PCs (N)", fontsize=12)
plt.ylabel("Inertia", fontsize=12)
plt.grid(True, linestyle="--", alpha=0.7)

plt.show()

# %%
from clustergram import Clustergram

cgram = Clustergram(range(1, 30))
cgram.fit(data[pca])

# %%
# 1. Create the plot
ax = cgram.plot(figsize=(20, 30))
ax.set_xticks(np.arange(1, 31))
ax.grid(True, which="both", color="black", linestyle="-", linewidth=0.5)

# %%
kmeans5 = cluster.KMeans(n_clusters=4, random_state=42)

# %%
kmeans5.fit(data[pca])

# %%
k = 4
labels = kmeans5.labels_

# Sort cluster centers by the first feature
sorted_centers_indices = np.argsort(kmeans5.cluster_centers_[:, 0])

# Reassign labels: the cluster with the smallest center gets label 0, etc.
new_labels = np.zeros_like(labels)
for i, cluster_idx in enumerate(sorted_centers_indices):
    new_labels[labels == cluster_idx] = i

data["kmeans_pca"] = new_labels

# %%
len(data["kmeans_pca"].unique())

# %%
labels

# %%
data[["kmeans_pca", "geometry"]].explore("kmeans_pca", categorical=True, cmap="tab20")

# %%
k5_means = data.groupby("kmeans_pca")[pca].mean()
k5_means.T.style.background_gradient(cmap="coolwarm", vmin=-5, vmax=5, axis=1)
